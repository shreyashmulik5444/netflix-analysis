# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
original_df = pd.read_csv('e:NetFlix.csv')

# %%
df = original_df.copy()

# %%
df.sample(5)
# Out:
#      show_id     type                          title       director  \
# 6284   s6655    Movie    The Meaning of Monty Python  Albert Sharpe
# 5836   s6251  TV Show                      The Crime            NaN
# 913    s1820    Movie                Don't Look Down  Daniel Gordon
# 4792   s5311    Movie    Russell Howard: Recalibrate    Peter Orton
# 5058   s5551    Movie  Shawn Mendes: Live in Concert   Paul Dugdale
#
#                                                    cast  \
# 6284                                                NaN
# 5836  Magdalena Boczarska, Wojciech Zieliński, Joann...
# 913                                     Richard Branson
# 4792                                     Russell Howard
# 5058                                       Shawn Mendes
#
#                             country date_added  release_year rating  duration  \
# 6284                 United Kingdom   2-Oct-18          2013  TV-MA        60
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7787 entries, 0 to 7786
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       7787 non-null   object
#  1   type          7787 non-null   object
#  2   title         7787 non-null   object
#  3   director      5398 non-null   object
#  4   cast          7069 non-null   object
#  5   country       7280 non-null   object
#  6   date_added    7777 non-null   object
#  7   release_year  7787 non-null   int64
#  8   rating        7780 non-null   object
#  9   duration      7787 non-null   int64
#  10  genres        7787 non-null   object
#  11  description   7787 non-null   object
# dtypes: int64(2), object(10)
# memory usage: 730.2+ KB

# %%
df.describe()
# Out:
#        release_year     duration
# count   7787.000000  7787.000000
# mean    2013.932580    69.122769
# std        8.757395    50.950743
# min     1925.000000     1.000000
# 25%     2013.000000     2.000000
# 50%     2017.000000    88.000000
# 75%     2018.000000   106.000000
# max     2021.000000   312.000000

# %%
df.duplicated().value_counts()
# Out:
# False    7787
# Name: count, dtype: int64

# %%
df.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2389
# cast             718
# country          507
# date_added        10
# release_year       0
# rating             7
# duration           0
# genres             0
# description        0
# dtype: int64

# %% [markdown]
# ## cleaning 'director' column

# %%
df['director'].isnull().value_counts()
# Out:
# director
# False    5398
# True     2389
# Name: count, dtype: int64

# %%
df['director'] = df['director'].fillna('unknown')

# %%
df['director'].notnull().value_counts()
# Out:
# director
# True    7787
# Name: count, dtype: int64

# %%
df.loc[df['director']=='unknown' , ['type','genres']]
# Out:
#          type                                             genres
# 0     TV Show  International TV Shows, TV Dramas, TV Sci-Fi &...
# 4     TV Show  British TV Shows, Docuseries, Science & Nature TV
# 10    TV Show               Anime Series, International TV Shows
# 15    TV Show                                           Kids' TV
# 17    TV Show                                           TV Shows
# ...       ...                                                ...
# 7777  TV Show  Crime TV Shows, International TV Shows, TV Dramas
# 7779  TV Show              TV Dramas, TV Mysteries, TV Thrillers
# 7780  TV Show    International TV Shows, TV Horror, TV Mysteries
# 7782  TV Show                 International TV Shows, Reality TV
# 7783  TV Show               Anime Series, International TV Shows
#
# [2389 rows x 2 columns]

# %% [markdown]
# ## cleaning the cast column

# %%
df['cast'].isnull().value_counts()
# Out:
# cast
# False    7069
# True      718
# Name: count, dtype: int64

# %%
df['cast'].unique()
# Out:
# array(['João Miguel, Bianca Comparato, Michel Gomes, Rodolfo Valente, Vaneza Oliveira, Rafael Lozano, Viviane Porto, Mel Fronckowiak, Sergio Mamberti, Zezé Motta, Celso Frateschi',
#        'Rajneesh Duggal, Adah Sharma, Indraneil Sengupta, Anjori Alagh, Rajendranath Zutshi, Vipin Sharma, Amin Hajee, Shri Vallabh Vyas',
#        'Reza Rahadian, Bunga Citra Lestari, Tara Basro, Chelsea Islan',
#        ...,
#        'Léa Seydoux, Adèle Exarchopoulos, Salim Kechiouche, Aurélien Recoing, Catherine Salée, Benjamin Siksou, Mona Walravens, Alma Jodorowsky, Jérémie Laheurte, Anne Loiret, Benoît Pilot, Sandor Funtek, Fanny Maurin',
#        'Cate Blanchett, Sally Hawkins, Alec Baldwin, Louis C.K., Bobby Cannavale, Andrew Dice Clay, Peter Sarsgaard, Michael Stuhlbarg, Tammy Blanchard, Max Casella, Alden Ehrenreich',
#        'Sarah Paulson, Mark Duplass, Clu Gulager'],
#       shape=(6832,), dtype=object)

# %%
df['cast'] = df['cast'].fillna('unknown')

# %%
df['cast'].notnull().sum()
# Out:
# np.int64(7787)

# %% [markdown]
# ## cleaning country

# %%
df['country'].isnull().sum()
# Out:
# np.int64(507)

# %%
df['country'] = df['country'].fillna('unknown country')

# %%
df['country'].notnull().sum()
# Out:
# np.int64(7787)

# %% [markdown]
# ## cleaning rating

# %%
df['rating'].isnull().sum()
# Out:
# np.int64(7)

# %%
df['rating'].unique()
# Out:
# array(['TV-MA', 'TV-PG', 'R', 'TV-G', 'PG-13', 'TV-14', 'TV-Y', 'PG',
#        'TV-Y7', 'NR', 'G', 'TV-Y7-FV', nan, 'UR', 'NC-17'], dtype=object)

# %%
df['rating'].isnull().sum()
# Out:
# np.int64(7)

# %%
df['rating'] = df['rating'].fillna('unrated')

# %%
df['rating'].isnull().sum()
# Out:
# np.int64(0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7787 entries, 0 to 7786
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       7787 non-null   object
#  1   type          7787 non-null   object
#  2   title         7787 non-null   object
#  3   director      7787 non-null   object
#  4   cast          7787 non-null   object
#  5   country       7787 non-null   object
#  6   date_added    7777 non-null   object
#  7   release_year  7787 non-null   int64
#  8   rating        7787 non-null   object
#  9   duration      7787 non-null   int64
#  10  genres        7787 non-null   object
#  11  description   7787 non-null   object
# dtypes: int64(2), object(10)
# memory usage: 730.2+ KB

# %%
df.head()
# Out:
#   show_id     type                                      title        director  \
# 0      s1  TV Show                                         3%         unknown
# 1     s10    Movie                                       1920    Vikram Bhatt
# 2    s100    Movie                                 3 Heroines  Iman Brotoseno
# 3   s1000    Movie  Blue Mountain State: The Rise of Thadland    Lev L. Spiro
# 4   s1001  TV Show                             Blue Planet II         unknown
#
#                                                 cast         country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...          Brazil
# 1  Rajneesh Duggal, Adah Sharma, Indraneil Sengup...           India
# 2  Reza Rahadian, Bunga Citra Lestari, Tara Basro...       Indonesia
# 3  Alan Ritchson, Darin Brooks, James Cade, Rob R...   United States
# 4                                 David Attenborough  United Kingdom
#
#   date_added  release_year rating  duration  \
# ...

# %% [markdown]
# # feature engineering

# %% [markdown]
# ### fe for 'date_added' column

# %%
df['date_added'] = pd.to_datetime(df['date_added'],errors='coerce') #errors='coerce': Valid date = converted properly , Invalid date = replaced with NaT

df['year_added'] = df['date_added'].dt.year # '.dt is a datetime accessor in pandas'
df['month_added'] = df['date_added'].dt.month
df['day_added'] = df['date_added'].dt.day
# Out:
# C:\Users\shrey\AppData\Local\Temp\ipykernel_2728\2999940046.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['date_added'] = pd.to_datetime(df['date_added'],errors='coerce') #errors='coerce': Valid date = converted properly , Invalid date = replaced with NaT

# %% [markdown]
# ## fe for 'country' column

# %%
#df['country'].unique()

# %%
df['country_count'] = df['country'].apply(lambda x: len(x.split(',')))

# %%
df['country_count']
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 7782    1
# 7783    1
# 7784    3
# 7785    1
# 7786    1
# Name: country_count, Length: 7787, dtype: int64

# %% [markdown]
# ## fe for rating

# %%
#Group into categories (better analysis)
def categorize_rating(r):
    if r in ['TV-Y', 'TV-Y7', 'TV-Y7-FV', 'G']:
        return 'Kids'
    elif r in ['TV-G', 'TV-PG', 'PG']:
        return 'Family'
    elif r in ['TV-14', 'PG-13']:
        return 'Teen'
    elif r in ['TV-MA', 'R', 'NC-17']:
        return 'Adult'
    else:
        return 'Unknown'

df['rating_category'] = df['rating'].apply(categorize_rating)

# %%
#df['genres'].unique()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7787 entries, 0 to 7786
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   show_id        7787 non-null   object
#  1   type           7787 non-null   object
#  2   title          7787 non-null   object
#  3   director       7787 non-null   object
#  4   cast           7787 non-null   object
#  5   country        7787 non-null   object
#  6   date_added     7777 non-null   datetime64[ns]
#  7   release_year   7787 non-null   int64
#  8   rating         7787 non-null   object
#  9   duration       7787 non-null   int64
#  10  genres         7787 non-null   object
#  11  description    7787 non-null   object
#  12  year_added     7777 non-null   float64
#  13  month_added    7777 non-null   float64
#  14  day_added      7777 non-null   float64
#  15  country_count  7787 non-null   int64
# dtypes: datetime64[ns](1), float64(3), int64(3), object(9)
# ...
